# %% [markdown]
# # LegalBench-RAG Evaluation Plots
#
# Load one or more JSONL trace files (written by `eval_precision_recall.py --trace-file`) and generate individual charts.

# %%
from __future__ import annotations
import json
from pathlib import Path

import matplotlib.pyplot as plt
import matplotlib

# %matplotlib inline
matplotlib.rcParams.update({
    "font.family":       "serif",
    "font.size":         11,
    "axes.titlesize":    13,
    "axes.titleweight":  "bold",
    "axes.labelsize":    12,
    "axes.labelweight":  "bold",
    "xtick.labelsize":   10,
    "ytick.labelsize":   10,
    "legend.fontsize":   9,
    "legend.frameon":    True,
    "legend.shadow":     False,
    "legend.edgecolor":  "0.8",
    "axes.spines.top":   False,
    "axes.spines.right": False,
    "axes.grid":         True,
    "grid.alpha":        0.4,
    "grid.linestyle":    "--",
    "figure.dpi":        150,
    "savefig.dpi":       300,
    "savefig.bbox":      "tight",
})

# %%
# ── Color / style maps ────────────────────────────────────────────────────────

# Substring of model label → named color (case-insensitive match)
# same model family (e.g. fine-tuned) use same color family
COLORS: dict[str, str] = {
    # ========= encoder+decoder (cold color) =========
    "all-mpnet":       "blue",
    "legal-embed-bge": "green",
    ### ----- no sentence training (seperate from the two above by using grey) ----
    "legalbert":       "grey",
    "legal-bert":      "grey",
    "bert-dpr-clerc":  "lightgrey",
    "clerc":           "lightgrey",
    # ========= decoder-only models (using warm color=========
    "octen":           "hotpink",
    "qwen3":           "pink",
    'text-embedding-3-large': "red",
    'text-embedding-3-large-semantic': "darkred",
    # "qwen2.5":         "cyan",
    # "gemini":          "olive",
}

FALLBACK_COLORS = [
    "purple", "brown", "cyan",
    "olive",
]

MARKERS    = ["o", "s", "^", "D", "v", "*", "P", "X", "h", "p"]
LINESTYLES = ["-", "--"]


def _resolve_color(label: str, used: set[str]) -> str:
    lower = label.lower()
    for key, color in COLORS.items():
        if key in lower and color not in used:
            return color
    for color in FALLBACK_COLORS:
        if color not in used:
            return color
    return FALLBACK_COLORS[len(used) % len(FALLBACK_COLORS)]


def assign_styles(runs: list[dict]) -> None:
    """Attach _style dict to each run in-place."""
    used: set[str] = set()
    for i, run in enumerate(runs):
        color = _resolve_color(run["run_info"]["label"], used)
        used.add(color)
        run["_style"] = {
            "color":     color,
            "marker":    MARKERS[i % len(MARKERS)],
            "linestyle": LINESTYLES[i % len(LINESTYLES)],
        }

# %%
# ── Data loading ──────────────────────────────────────────────────────────────

def load_run_summary(path: Path | str) -> dict | None:
    """Read a trace JSONL and return the run_summary record, or None."""
    path = Path(path)
    summary = None
    with open(path, encoding="utf-8") as fh:
        for line in fh:
            line = line.strip()
            if not line:
                continue
            try:
                rec = json.loads(line)
            except json.JSONDecodeError:
                continue
            if rec.get("_type") == "run_summary":
                summary = rec
    if summary is None:
        print(f"WARNING: no run_summary in {path} — skipped")
    return summary


def load_runs(*paths: str | Path) -> list[dict]:
    """Load multiple trace files, assign styles, return run list."""
    runs = [r for p in paths if (r := load_run_summary(p)) is not None]
    assign_styles(runs)
    return runs

# %%
# ── Core plot function ────────────────────────────────────────────────────────

def plot_one(
    runs: list[dict],
    metric_key: str,
    *,
    section: str = "overall",          # "overall" or a benchmark name
    title: str | None = None,
    y_label: str | None = None,
    ylim: tuple[float, float] = (0.0, 1.0),
    figsize: tuple[float, float] = (9, 5),
    save_to: str | Path | None = None,
    fmt: str = "png",
) -> None:
    """
    Plot one metric across all runs.

    Parameters
    ----------
    runs       : list returned by load_runs()
    metric_key : one of char_recall_at_k / char_precision_at_k /
                 chunk_recall_at_k / chunk_precision_at_k
    section    : "overall" (default) or a benchmark name like "cuad"
    ylim       : y-axis limits — tune per chart since recall/precision scale differently
    save_to    : file path to save (without extension); if None, just display
    """
    # Collect K values from the first run that has data
    all_ks: list[int] = []
    for run in runs:
        ds = run.get("overall", {}) if section == "overall" else run.get("benchmarks", {}).get(section, {})
        if md := ds.get(metric_key):
            all_ks = sorted(int(k) for k in md)
            break

    fig, ax = plt.subplots(figsize=figsize)

    for run in runs:
        ds = run.get("overall", {}) if section == "overall" else run.get("benchmarks", {}).get(section, {})
        md = ds.get(metric_key, {})
        if not md:
            continue
        ks   = sorted(int(k) for k in md)
        vals = [md[str(k)] for k in ks]
        s    = run["_style"]
        label = run["run_info"]["label"].split("/")[-1]
        ax.plot(ks, vals, label=label,
                color=s["color"], marker=s["marker"],
                linestyle=s["linestyle"], linewidth=2.0, markersize=7)

    max_k = all_ks[-1] if all_ks else 0
    ax.set_xticks(range(0, max_k + 1, 10))
    ax.set_xlim(left=0, right=max_k+5)
    ax.set_ylim(ylim)
    ax.set_xlabel("K (Retrieval Depth)")
    ax.set_ylabel(y_label or metric_key.replace("_at_k", "").replace("_", " ").title())
    ax.set_title(title or f"{metric_key.replace('_at_k', '').replace('_', ' ').title()} — {section}")
    if ax.get_lines():
        ax.legend(loc="best")
    fig.tight_layout()

    if save_to:
        dest = Path(save_to).with_suffix(f".{fmt}")
        dest.parent.mkdir(parents=True, exist_ok=True)
        fig.savefig(dest)
        print(f"Saved → {dest}")

    plt.show()

# %% [markdown]
# ---
# ## Load runs

# %%
EVAL_ROOT = Path("logs/eval/legalbenchrag-mini")
QUERY_TYPE = ['original', 'gemini_3', 'qwen3.5']
model_location = EVAL_ROOT / QUERY_TYPE[0]

# runs = load_runs(
#     model_location/ "lbr_hier_all-mpnet.jsonl",
#     model_location/ "lbr_hier_clerc.jsonl",
#     model_location/ "lbr_hier_legalbert.jsonl",
#     model_location/ "lbr_hier_legal-embed-bge.jsonl",
#     model_location/ "lbr_hier_octen.jsonl",
#     model_location/ "lbr_hier_qwen3.jsonl",
# )

runs = load_runs(
    model_location/ "lbr_hier_text-embedding-3-large-semantic.jsonl",

    model_location/ "lbr_hier_text-embedding-3-large.jsonl",
    model_location/ "lbr_hier_all-mpnet-base-v2.jsonl",
    model_location/ "lbr_hier_qwen3.jsonl",
    model_location/ "lbr_hier_legal-embed-bge-base-en-v1.5.jsonl",
    model_location/ "lbr_hier_octen.jsonl",
    #model_location/ "lbr_hier_clerc.jsonl",
    model_location/ "lbr_hier_legalbert.jsonl",

    model_location/ "lbr_hier_text-embedding-3-large-lexical.jsonl",
)

runs[1]["run_info"]["label"] = "text-embedding-3-large"
runs[1]["_style"]["color"]   = "red"
runs[1]["_style"]["linestyle"]   = "-"


runs[0]["run_info"]["label"] = "text-embedding-3-large (semantic)"
runs[0]["_style"]["color"]   = "lightcoral"
runs[0]["_style"]["linestyle"]   = "-"

runs[-1]["run_info"]["label"] = "text-embedding-3-large (lexical)"
runs[-1]["_style"]["color"]   = "firebrick"
runs[-1]["_style"]["linestyle"]   = "-"

print(f"Loaded {len(runs)} runs:")
for r in runs:
    print(" ", r["run_info"]["label"], "  ks:", r["run_info"]["ks"])
# Out:
# Loaded 8 runs:
#   text-embedding-3-large (semantic)   ks: [1, 2, 4, 8, 16, 32, 64]
#   text-embedding-3-large   ks: [1, 2, 4, 8, 16, 32, 64]
#   sentence-transformers/all-mpnet-base-v2   ks: [1, 2, 4, 8, 16, 32, 64]
#   Qwen/Qwen3-Embedding-0.6B   ks: [1, 2, 4, 8, 16, 32, 64]
#   axondendriteplus/Legal-Embed-bge-base-en-v1.5   ks: [1, 2, 4, 8, 16, 32, 64]
#   Octen/Octen-Embedding-0.6B   ks: [1, 2, 4, 8, 16, 32, 64]
#   nlpaueb/legal-bert-base-uncased   ks: [1, 2, 4, 8, 16, 32, 64]
#   text-embedding-3-large (lexical)   ks: [1, 2, 4, 8, 16, 32, 64]

# %%
manual_run = {
    "run_info": {
        "label": "rerun-paper-code",   # change to whatever label you want
        "ks": [4, 16, 32, 64],
    },
    "overall": {
        "char_recall_at_k": {
            "4":  0.20527527117645500,
            "16": 0.42364473861988400,
            "32": 0.53743308843523300,
            "64": 0.65321418368524800,
        },
        "char_precision_at_k": {
            "4":  0.07221383905916540,
            "16": 0.04306450760417140,
            "32": 0.02934247964638140,
            "64": 0.01910996279721250,
        },
    },
    "benchmarks": {},
    "_style": {
        "color":     "black",
        "marker":    "D",
        "linestyle": "--",
    },
}

# runs.append(manual_run)

# %% [markdown]
# ---
# ## Overall — Recall

# %%
plot_one(
    runs,
    "chunk_recall_at_k",
    section="overall",
    title="Chunk-Level Recall@K — Overall",
    y_label="ChunkRecall@K",
    ylim=(0.0, 1),
    #save_to= f"{model_location}/figures/overall_chunk_recall",
)

# %%
plot_one(
    runs,
    "char_recall_at_k",
    section="overall",
    title="Character-Level Recall@K — Overall",
    y_label="CharRecall@K",
    ylim=(0.0, 1),
    #save_to=f"{model_location}/figures/overall_char_recall",
)

# %% [markdown]
# ---
# ## Overall — Precision

# %%
plot_one(
    runs,
    "chunk_precision_at_k",
    section="overall",
    title="Chunk-Level Precision@K — Overall",
    y_label="ChunkPrecision@K",
    ylim=(0.0, 0.2),
    #save_to=f"{model_location}/figures/overall_chunk_precision",
)

# %%
plot_one(
    runs,
    "char_precision_at_k",
    section="overall",
    title="Character-Level Precision@K — Overall",
    y_label="CharPrecision@K",
    ylim=(0.0, 0.1),
    #save_to=f"{model_location}/figures/overall_char_precision",
)

# %% [markdown]
# ---
# ## Per-benchmark — contractnli

# %%
plot_one(runs,
        "chunk_recall_at_k",
        section="contractnli",
        title="Chunk Recall@K — contractnli",    
        y_label="ChunkRecall@K",    
        ylim=(0.0, 0.9))
plot_one(runs, "chunk_precision_at_k", 
         section="contractnli", 
         title="Chunk Precision@K — contractnli", 
         y_label="ChunkPrecision@K", 
         ylim=(0.0, 0.15))

# %% [markdown]
# ---
# ## Per-benchmark — cuad

# %%
plot_one(runs, "chunk_recall_at_k",    
         section="cuad", 
         title="Chunk Recall@K — cuad",    
         y_label="ChunkRecall@K",    
         ylim=(0.0, 0.9))
plot_one(runs, "chunk_precision_at_k", 
         section="cuad", 
         title="Chunk Precision@K — cuad", 
         y_label="ChunkPrecision@K", 
         ylim=(0.0, 0.15))

# %% [markdown]
# ---
# ## Per-benchmark — maud

# %%
plot_one(runs, "chunk_recall_at_k",    
         section="maud", 
         title="Chunk Recall@K — maud",    
         y_label="ChunkRecall@K",    
         ylim=(0.0, 0.9))
plot_one(runs, "chunk_precision_at_k", 
         section="maud", 
         title="Chunk Precision@K — maud", 
         y_label="ChunkPrecision@K", 
         ylim=(0.0, 0.01))

# %% [markdown]
# ---
# ## Per-benchmark — privacy_qa

# %%
plot_one(runs, "chunk_recall_at_k",    
         section="privacy_qa", 
         title="Chunk Recall@K — privacy_qa",    
         y_label="ChunkRecall@K",    
         ylim=(0.0, 0.9))
plot_one(runs, "chunk_precision_at_k", 
         section="privacy_qa", 
         title="Chunk Precision@K — privacy_qa", 
         y_label="ChunkPrecision@K", 
         ylim=(0.0, 0.30))
